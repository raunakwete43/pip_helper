# %%
import requests
import click
from bs4 import BeautifulSoup

# %%
name = input("Enter the name of pip module to search: ")
name = name.replace(" ", "")
URL = f"https://pypi.org/search/?q={name}&o="
request = requests.get(url=URL)
# Out:
# Enter the name of pip module to search:  numpy

# %%
soup = BeautifulSoup(request.content, "html.parser")

pages = soup.find("strong")
try:
    no_of_searches = int(pages.text)
except ValueError:
    no_of_searches = 40
    
if no_of_searches > 40:
    no_of_searches = 40
    
no_of_pages = ((no_of_searches) // 20) + 2

# %%
title = []
version = []
description = []
package_data = {}
for page in range(1, no_of_pages):
    URL = f"https://pypi.org/search/?o=&q={name}&page={page}"
    new_request = requests.get(url=URL)
    new_soup = BeautifulSoup(new_request.content, "html.parser")
    
    # Parse data from the current page
    names = new_soup.find_all("span", attrs={"class": "package-snippet__name"})
    vers = new_soup.find_all("span", attrs={"class": "package-snippet__version"})
    des = new_soup.find_all("p", attrs={"class": "package-snippet__description"})
    
    # Check if the lists have the same length after appending
    if len(names) == len(vers) == len(des):
        title += [name.text for name in names]
        version += [ver.text for ver in vers]
        description += [descr.text for descr in des]
    else:
        print(f"Warning: Inconsistent data on page {page}")

# %%
for index, (pkg_title, pkg_version, pkg_description) in reversed(list(enumerate(zip(title, version, description), start=1))):
    # print(f"{index}. Name: {pkg_title}")
    # print(f"   Version: {pkg_version}")
    # print(f"   Description: {pkg_description}\n")
    click.echo(f"{click.style(str(index), fg='blue', bold=True)}. Name: {click.style(pkg_title, fg='green', bold=True)}")
    click.echo(f"   Version: {pkg_version}")
    click.echo(f"   Description: {click.style(pkg_description, italic=True)}\n")
# Out:
# 60. Name: guillotina-numpy
#    Version: 1.0.1
#    Description:
#
# 59. Name: wandb2numpy
#    Version: 0.1
#    Description: Library to export data from WandB to numpy arrays or csv files.
#
# 58. Name: numpy-html
#    Version: 1.0.0
#    Description: A simple table renderer for numpy arrays. Provides a rich display hook for use with Jupyter Lab / Notebook.
#
# 57. Name: numpy_display
#    Version: 1.2.0
#    Description: Formats numpy matrices in an IPython Notebook
#
# 56. Name: numpy-mkp2020
#    Version: 1.14.5
#    Description: NumPy: array processing for numbers, strings, records, and objects.
#
# 55. Name: numpy-flow
#    Version: 0.0.1
#    Description: Nothing at all.
#
# 54. Name: numpy-posit
#    Version: 1.15.2.0.0.1.dev2
#    Description: posit (unum type III) integrated NumPy.
#
# 53. Name: lovely-numpy
#    Version: 0.2.9
#    Description: 💟 Lovely numpy
#
# 52. Name: sqlite-numpy
#    Version: 0.2.1
#    Description: Fast SQLite to numpy array loader
#
# 51. Name: pydantic-numpy
#    Version: 4.0.0
#    Description: Pydantic Model integration of the NumPy array
#
# 50. Name: numpy2tfrecord
#    Version: 0.0.3
#    Description: Convert a collection of numpy data to tfrecord
#
# 49. Name: BSON-NumPy
#    Version: 0.1
#    Description: Module for converting directly from BSON to NumPy ndarrays and vice versa
#
# 48. Name: numpy-financial
#    Version: 1.0.0
#    Description: Simple financial functions
#
# 47. Name: numpy-ringbuffer
#    Version: 0.2.2
#    Description: Ring buffer implementation for numpy
#
# 46. Name: numpy-dataframe
#    Version: 0.1.7
#    Description: A simple dataframe implementation using numpy as its basic element
#
# 45. Name: numpy-sugar
#    Version: 1.5.4
#    Description: Missing NumPy functionalities
#
# 44. Name: numpy-cloud
#    Version: 0.0.5
#    Description: Numpy in the cloud
#
# 43. Name: video2numpy
#    Version: 2.3.3
#    Description: Video reading into numpy
#
# 42. Name: mlphys-numpy
#    Version: 1.0.4
#    Description: Machine Learning for Physical Sciences
#
# 41. Name: hypothesis-numpy2
#    Version: 0.1.2
#    Description: Provides strategies for generating various `numpy` objects
#
# 40. Name: deuces-numpy
#    Version: 0.5
#    Description:
#
# 39. Name: numpy-groupies
#    Version: 0.10.2
#    Description: Optimised tools for group-indexing operations: aggregated sum and more.
#
# 38. Name: numpy-syncer
#    Version: 0.0.1
#    Description: Manage a Numpy data structure using Peewee-Sync
#
# 37. Name: ros2-numpy
#    Version: 0.0.4
#    Description: Convert ROS2 messages to and from numpy arrays
#
# 36. Name: concretefhe-numpy
#    Version: 0.0.10
#    Description: Concrete numpy for the Concrete Framework
#
# 35. Name: intel-numpy
#    Version: 1.21.4
#    Description: NumPy is the fundamental package for array computing with Python.
#
# 34. Name: numpy-ros
#    Version: 0.1.3
#    Description: Seamlessly convert between ROS messages and NumPy arrays.
#
# 33. Name: numpy-linreg
#    Version: 0.1.2
#    Description: Linear Regression with numpy only.
#
# 32. Name: idx2numpy
#    Version: 1.2.3
#    Description: A Python package which provides tools to convert files to and from IDX format (described at http://yann.lecun.com/exdb/mnist/) into numpy.ndarray.
#
# 31. Name: numpy-ops1234567890
#    Version: 1.0.0
#    Description: A simple package to do numpy power operation
#
# 30. Name: dicom-numpy
#    Version: 0.6.5
#    Description: Extract image data into a 3D numpy array from a set of DICOM files.
#
# 29. Name: numpy-linalg
#    Version: 0.1
#    Description: Collection of wrapper classes to make it easier (more readable) to work with NumPy
#
# 28. Name: numpy-nn
#    Version: 0.2.6
#    Description: Numpy NN is a Deep Neural Network Package which is built on base Numpy operations. This project is under development and any contributions are welcome.
#
# 27. Name: preconvert_numpy
#    Version: 0.0.3
#    Description: Preconverts common numpy types to their serializable (jsonifiable, msgpackable, etc...) form.
#
# 26. Name: numpy-partition
#    Version: 1.18.9
#    Description: SQL PARTITION BY and window functions for NumPy
#
# 25. Name: numpy-allocator
#    Version: 1.2.0
#    Description: Configurable memory allocations
#
# 24. Name: nn-numpy
#    Version: 0.0.1
#    Description: A package which contains a simple implementation of neural network with numpy
#
# 23. Name: numpy-turtle
#    Version: 0.2
#    Description: Turtle graphics with NumPy
#
# 22. Name: pydantic-numpy
#    Version: 4.0.0
#    Description: Pydantic Model integration of the NumPy array
#
# 21. Name: numpy2tfrecord
#    Version: 0.0.3
#    Description: Convert a collection of numpy data to tfrecord
#
# 20. Name: BSON-NumPy
#    Version: 0.1
#    Description: Module for converting directly from BSON to NumPy ndarrays and vice versa
#
# 19. Name: numpy-financial
#    Version: 1.0.0
#    Description: Simple financial functions
#
# 18. Name: numpy-ringbuffer
#    Version: 0.2.2
#    Description: Ring buffer implementation for numpy
#
# 17. Name: numpy-dataframe
#    Version: 0.1.7
#    Description: A simple dataframe implementation using numpy as its basic element
#
# 16. Name: numpy-sugar
#    Version: 1.5.4
#    Description: Missing NumPy functionalities
#
# 15. Name: numpy-cloud
#    Version: 0.0.5
#    Description: Numpy in the cloud
#
# 14. Name: video2numpy
#    Version: 2.3.3
#    Description: Video reading into numpy
#
# 13. Name: mlphys-numpy
#    Version: 1.0.4
#    Description: Machine Learning for Physical Sciences
#
# 12. Name: hypothesis-numpy2
#    Version: 0.1.2
#    Description: Provides strategies for generating various `numpy` objects
#
# 11. Name: mapchete-numpy
#    Version: 0.1
#    Description: Mapchete NumPy read/write extension
#
# 10. Name: numpy-serializer
#    Version: 0.1.3
#    Description: Preserve numpy arrays shapes while serializing them to bytes
#
# 9. Name: topas2numpy
#    Version: 0.2.0
#    Description: Python functions for reading TOPAS result files
#
# 8. Name: numpy-cursor
#    Version: 1.0.5
#    Description: This package contains a Python implementation of a cursor for NumPy matrices. The cursor allows you to conveniently move through a matrix and read or modify its values.
#
# 7. Name: numpy-illustrated
#    Version: 0.3.1
#    Description: Helper functions from the NumPy Illustrated guide
#
# 6. Name: numpy-camera
#    Version: 0.0.2
#    Description: ???
#
# 5. Name: numpy-io
#    Version: 0.0.8
#    Description: an easy training architecture
#
# 4. Name: numpy-onlinestats
#    Version: 0.1.0
#    Description: Online statistics for Numpy arrays.
#
# 3. Name: gdal2numpy
#    Version: 0.0.239
#    Description: An utils functions package
#
# 2. Name: numpy1
#    Version: 0.0.1
#    Description: Python
#
# 1. Name: numpy
#    Version: 1.26.0
#    Description: Fundamental package for array computing in Python

# %%
index = int(input("Select the package to install: "))
command = f"pip install {title[index - 1]}"
command
